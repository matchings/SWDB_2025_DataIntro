# %% [markdown]
# ![cropped-SummerWorkshop_Header.png](attachment:02a8fa98-5280-4e58-972b-b49e606371b3.png)

# %% [markdown]
# <h1 align="center">DAY 1 Workshop 1 SWDB 2025 </h1>
# <h3 align="center">Monday, August 25, 2025</h3>
# <h3 align="center">Introduction to the SWDB Datasets</h3>

# %% [markdown]
# <div style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; ">
#
# <h2>Objectives</h2>
#
# In this workshop, we will briefly introduce the datasets made available for SWDB, walking through how to load, find, and access key data pieces and metadata. After working through the material, you will learn:
# * how to use the AllenSDK and pynwb to load and access the data
# * how to search the metadata for information about the datasets and experiments
# * about the features and limitations of each dataset to help you select the right data for your scientific question
#
# </div>

# %% [markdown]
# <div style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; ">
#
# Outline:
#
#     1. general data access patterns
#         AllenSDK
#         pynwb
#             NWBHDF5IO
#             NWBZarrIO
#             nwbwidget
#         add a schematic outlining basic AllenSDK functionality (bonus how that relates to pynwb functions)
#
#     2. how to find and access key data components
#             select a pynwb and an AllenSDK example (ephys and ophys)
#             navigate to data pieces using nwbwidget, AllenSDK
#
#             exercise:
#                 load traces
#                 load stimulus table (identify what kind of behavior and/or stimulus)
#                 plot stim aligned response
#
#     3. find information about the dataset and experiment using metadata
#             provide high-level overview of metadata schemas for AllenSDK and AIND datasets, tools for navigating metadata
#             (note that we will curate a dataframe of select metadata fields for AIND datasets that will be easier to query than the original jsons)
#
#             example of how to extract information from metadata for a sample dataset
#
#             group exercise:
#                 form small groups and assign a dataset to fill out a super table with information about each dataset
#
#                 fields:
#                     modality
#                     timescale
#                     anatomy (brain area, depth)
#                     cell type
#                     population size
#                     stimuli (visual stim, rewards)
#                     behavioral measures (running, etc)
#                     manipulation (optogenetics, drugs, anesthesia, etc)
#
# </div>

# %% [markdown]
# <div style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; ">
# <h2>Datasets </h2>
#
# * Visual Coding 2p
# * Visual Coding Neuropixels
# * Visual Behavior 2p
# * Visual Behavior Neuropixels
# * V1 Deep Dive 2p & EM
# * Cell Type Look Up Table Neuropixels
# * Neuropixels Ultra Psychedelics
# * Brain Computer Interface 2p
# * Dynamic Foraging Behavior (and Neuropixels?)

# %% [markdown]
# <div style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; ">
# <h2>Data file types and data access tools</h2>
#
# Neurodata Without Borders:
#
# AllenSDK:
#
# pyNWB:

# %%
# imports 
import pynwb
import hdmf
# from nwbwidgets import nwb2widget
import pandas as pd 
import os

# %%
# import platform
# platstring = platform.platform()

# if 'Darwin' in platstring:
#     # macOS 
#     data_root = "/Volumes/Brain2024/"
# elif 'Windows'  in platstring:
#     # Windows (replace with the drive letter of USB drive)
#     data_root = "E:/"
# elif ('amzn' in platstring):
#     # then on CodeOcean
#     data_root = "/data/"
# else:
#     # then your own linux platform
#     # EDIT location where you mounted hard drive
#     data_root = "/media/$USERNAME/Brain2024/"

# %%
# # import behavior project cache class from SDK to be able to load the data
# from allensdk.brain_observatory.ecephys.ecephys_project_cache import EcephysProjectCache

# manifest_path = os.path.join(data_root,'allen-brain-observatory/visual-coding-neuropixels/ecephys-cache/manifest.json') 

# cache = EcephysProjectCache.from_warehouse(manifest=manifest_path)

# %%
# session_id = 767871931

# session = cache.get_session_data(session_id)

# %%
# AllenSDK example 

# will include infographic outlining general patterns for using AllenSDK

# %%
# # HDF5 example 
# nwbfile_path_zarr = 

# with NWBHDF5IO(filepath, mode='r') as io:
#     nwbfile = io.read()

# %%
# Zarr example 
from hdmf_zarr import NWBZarrIO 

nwbfile_path_zarr = '/data/single-plane-ophys_731015_2025-01-24_20-00-44_processed_2025-05-10_22-05-27/single-plane-ophys_731015_2025-01-24_20-00-44_behavior_nwb'

with NWBZarrIO(nwbfile_path_zarr, mode='r') as io:
    nwbfile_zarr = io.read()
# Out:
# /opt/conda/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'core' version 2.7.0 because version 2.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."

# %% [markdown]
# <div style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; ">
# <h2>Load a dataset</h2>

# %% [markdown]
# select a dataset of interest. show how to load the data, pull out the traces, stim tables, and plot stim-aligned responses

# %%
# # show two examples: 
#     AllenSDK (cache)
#     pynwb (nwb2widget)

# %%
from nwbwidgets import nwb2widget 

nwb2widget(nwbfile_zarr)

# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
#
# **Exercise:** Plot a stimulus-aligned neural activity trace.
#
# </div>

# %% [markdown]
# <div style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; ">
# <h4>1. Load the neural activity traces</h4>

# %%
# 1. Store the neural activity trace 

# # If modality is 2p 
# dff = 

# If modality is ecephys
# units =

# %% [markdown]
# <div style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; ">
# <h4>2. Load the stimulus table</h4>

# %%
stim_table =

# %% [markdown]
# <div style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; ">
# <h4>3. Plot a stimulus-aligned neural activity trace</h4>

# %% [markdown]
# <div style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; ">
# <h2>Using metadata to find information about the dataset </h2>

# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
#
# **Exercise:** Together, we'll construct a super-table with key information that helps us understand the features and constraints of each dataset. Form small groups and we will assign you a dataset to scrape the metadata fields to fill out the table.
# </div>

# %% [markdown]
# Field Descriptions:
# * modality
# * timescale
# * anatomy (brain area, depth)
# * cell type
# * population size
# * stimuli (visual stim, rewards)
# * behavioral measures (running, etc)
# * manipulation (optogenetics, drugs, anesthesia, etc)

# %%
# Set column and dataset names 
column_names = ['dataset', 'modality', 'timescale', 'anatomy', 'cell_type', 'population_size', 'stimuli', 'behavioral_measures', 'manipulation'] 
dataset_names = ['Visual Coding 2p', 'Visual Coding NP', 'Visual Beh 2p', 'Visual Beh NP', 'V1DD 2p', 'V1DD EM', 'CTLUT NP', 'NP Ultra Psych', 'BCI 2p', 'Dynamic Foraging'] 

# Construct table 
metadata_table_template = pd.DataFrame(columns=column_names)
metadata_table_template.dataset = dataset_names

metadata_table_template

# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
#
# **Discussion:**
# Select a dataset and discuss:
# 1. What interests you about the dataset? What are unique features that distinguish it from others?
# 2. What are some scientific questions you could answer with this dataset? What are the next steps you would take to approach the question?
# 2. Are there any limitations to consider or uncertainties to verify before working with this dataset?
# </div>
